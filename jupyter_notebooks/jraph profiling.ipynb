# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

BASE_DIR = '/home/dts/Documents/hu'
PROFILING_CSV = 'parsed_profiling_qm9_aflow_schnet_100k_steps_23_54__8_03_2024.csv'

# %%
profiling_df = pd.read_csv(os.path.join(BASE_DIR, PROFILING_CSV))

# %%
profiling_df
# Out:
#                        model time_day  dataset  batching_type batch_size  \
# schnet  00_29_31__09_03_2024      qm9  dynamic             16   gpu_a100
# schnet  00_29_31__09_03_2024      qm9  dynamic             16   gpu_a100
# schnet  00_29_31__09_03_2024      qm9  dynamic             16   gpu_a100
# schnet  00_29_31__09_03_2024      qm9  dynamic             16   gpu_a100
# schnet  00_29_31__09_03_2024      qm9  dynamic             16   gpu_a100
# ...                      ...      ...      ...            ...        ...
# schnet  00_29_31__09_03_2024    aflow   static            128        cpu
# schnet  00_29_31__09_03_2024    aflow   static            128        cpu
# schnet  00_29_31__09_03_2024    aflow   static            128        cpu
# schnet  00_29_31__09_03_2024    aflow   static            128        cpu
# schnet  00_29_31__09_03_2024    aflow   static            128        cpu
#
#         computing_type  iteration  \
# schnet               0       True
# schnet               1       True
# schnet               2       True
# schnet               3       True
# schnet               4       True
# ...                ...        ...
# schnet               5       True
# schnet               6       True
# schnet               7       True
# schnet               8       True
# schnet               9       True
#
#                                      experiment_completed  \
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# ...                                                   ...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
#
#                                           submission_path  path  \
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     1
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     1
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     1
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     1
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     1
# ...                                                   ...   ...
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     4
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     4
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     4
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     4
# schnet  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...     4
#
#        recompilation_counter  step_100000_train_rmse  step_100000_val_rmse  \
# schnet           round_False                0.496274              0.486849
# schnet           round_False                0.498804              0.489333
# schnet           round_False                0.499049              0.489543
# schnet           round_False                0.499446              0.490024
# schnet           round_False                0.498325              0.488931
# ...                      ...                     ...                   ...
# schnet           round_False                0.101572              0.187537
# schnet           round_False                0.101572              0.187537
# schnet           round_False                0.101572              0.187537
# schnet           round_False                0.101572              0.187537
# schnet           round_False                0.101572              0.187537
#
#         step_100000_test_rmse  step_100000_batching_time  \
# schnet               0.492203                   0.000635
# schnet               0.494760                   0.000628
# schnet               0.495005                   0.000629
# schnet               0.495414                   0.000643
# schnet               0.494346                   0.000638
# ...                       ...                        ...
# schnet               0.107383                   0.003562
# schnet               0.107383                   0.003389
# schnet               0.107383                   0.003243
# schnet               0.107383                   0.003038
# schnet               0.107383                   0.003460
#
#         step_100000_update_time
# schnet                 0.001995
# schnet                 0.001982
# schnet                 0.001970
# schnet                 0.001982
# schnet                 0.001986
# ...                         ...
# schnet                 0.057649
# schnet                 0.057418
# schnet                 0.057254
# schnet                 0.056972
# schnet                 0.057490
#
# [320 rows x 16 columns]

# %%
profiling_df[profiling_df['computing_type'] == 'gpu_a100']
# Out:
#      model              time_day  dataset  batching_type  batch_size  \
# 0    aflow  07_50_17__15_02_2024  dynamic           True          16
# 1    aflow  07_50_17__15_02_2024  dynamic           True          16
# 2    aflow  07_50_17__15_02_2024  dynamic           True          16
# 3    aflow  07_50_17__15_02_2024  dynamic           True          16
# 4    aflow  07_50_17__15_02_2024  dynamic           True          16
# ..     ...                   ...      ...            ...         ...
# 143  aflow  07_50_18__15_02_2024   static           True         128
# 144  aflow  07_50_18__15_02_2024   static           True         128
# 145  aflow  07_50_18__15_02_2024   static           True         128
# 146  aflow  07_50_18__15_02_2024   static           True         128
# 147  aflow  07_50_18__15_02_2024   static           True         128
#
#     computing_type  iteration  experiment_completed  \
# 0         gpu_a100          0                 False
# 1         gpu_a100          1                 False
# 2         gpu_a100          2                 False
# 3         gpu_a100          3                 False
# 4         gpu_a100          4                 False
# ..             ...        ...                   ...
# 143       gpu_a100          5                  True
# 144       gpu_a100          6                  True
# 145       gpu_a100          7                  True
# 146       gpu_a100          8                  True
# 147       gpu_a100          9                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_aflow_schnet_unlimited_data_...
# 1    /u/dansp/batching_aflow_schnet_unlimited_data_...
# 2    /u/dansp/batching_aflow_schnet_unlimited_data_...
# 3    /u/dansp/batching_aflow_schnet_unlimited_data_...
# 4    /u/dansp/batching_aflow_schnet_unlimited_data_...
# ..                                                 ...
# 143  /u/dansp/batching_aflow_schnet_unlimited_data_...
# 144  /u/dansp/batching_aflow_schnet_unlimited_data_...
# 145  /u/dansp/batching_aflow_schnet_unlimited_data_...
# 146  /u/dansp/batching_aflow_schnet_unlimited_data_...
# 147  /u/dansp/batching_aflow_schnet_unlimited_data_...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_aflow_schnet_unlimited_data_...                      1
# 1    /u/dansp/batching_aflow_schnet_unlimited_data_...                      1
# 2    /u/dansp/batching_aflow_schnet_unlimited_data_...                      1
# 3    /u/dansp/batching_aflow_schnet_unlimited_data_...                      1
# 4    /u/dansp/batching_aflow_schnet_unlimited_data_...                      1
# ..                                                 ...                    ...
# 143  /u/dansp/batching_aflow_schnet_unlimited_data_...                      4
# 144  /u/dansp/batching_aflow_schnet_unlimited_data_...                      4
# 145  /u/dansp/batching_aflow_schnet_unlimited_data_...                      4
# 146  /u/dansp/batching_aflow_schnet_unlimited_data_...                      4
# 147  /u/dansp/batching_aflow_schnet_unlimited_data_...                      4
#
#      step_10000_train_rmse  step_10000_val_rmse  step_10000_test_rmse  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                      NaN                  NaN                   NaN
# ..                     ...                  ...                   ...
# 143               0.421525             0.308739              0.315714
# 144               0.421525             0.308740              0.315712
# 145               0.421525             0.308742              0.315713
# 146               0.421525             0.308743              0.315713
# 147               0.421524             0.308739              0.315713
#
#      step_10000_batching_time  step_10000_update_time
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ..                        ...                     ...
# 143                  2.148983                2.152476
# 144                  2.158815                2.162307
# 145                  2.149451                2.152938
# 146                  2.146149                2.149697
# 147                  2.159081                2.162566
#
# [78 rows x 16 columns]

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'gpu_a100']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time': 'Mean batching time (s)',
    'step_100000_update_time': 'Mean update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Mean batching time (s)', 'Mean update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()


# gpu_profiling_df.set_index('batch_size', inplace=True)
# gpu_profiling_df = gpu_profiling_df.rename(
#     columns={"step_10000_batching_time": 'batching_time', 'step_10000_update_time': 'update_time'})
# gpu_profiling_df
# Out:
# Empty DataFrame
# Columns: [Algorithm, Mean batching time (s), Mean update time (s)]
# Index: []

# %%
cpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
cpu_profiling_df = cpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_10000_batching_time': 'Mean batching time (s)',
    'step_10000_update_time': 'Mean update time (s)'})

cpu_profiling_df_grouped = cpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Mean batching time (s)', 'Mean update time (s)']

pd.options.display.float_format = "{:,.4f}".format

cpu_profiling_df_grouped = cpu_profiling_df_grouped[list_of_cols_to_display]
cpu_profiling_df_grouped.std()
# Out:
#                       Mean batching time (s)  Mean update time (s)
# Algorithm Batch size
# dynamic   16                             NaN                   NaN
#           32                          0.0000                0.0001
#           64                          0.0000                0.0001
# static    16                          0.0001                0.0002
#           32                          0.0004                0.0005
#           64                          0.0012                0.0012

# %% [markdown]
# # QM 9 - SchNet

# %%
qm9_schnet_PROFILING_CSV = 'parsed_qm9_schnet_unlimited_10k_steps_07_52__15_02_2024.csv'

# %%
profiling_df = pd.read_csv(os.path.join(BASE_DIR, qm9_schnet_PROFILING_CSV))

# %%
profiling_df
# Out:
#     model              time_day  dataset  batching_type  batch_size  \
# 0     qm9  07_53_33__15_02_2024  dynamic           True          16
# 1     qm9  07_53_33__15_02_2024  dynamic           True          16
# 2     qm9  07_53_33__15_02_2024  dynamic           True          16
# 3     qm9  07_53_33__15_02_2024  dynamic           True          16
# 4     qm9  07_53_33__15_02_2024  dynamic           True          16
# ..    ...                   ...      ...            ...         ...
# 140   qm9  07_53_33__15_02_2024   static           True         128
# 141   qm9  07_53_33__15_02_2024   static           True         128
# 142   qm9  07_53_33__15_02_2024   static           True         128
# 143   qm9  07_53_33__15_02_2024   static           True         128
# 144   qm9  07_53_33__15_02_2024   static           True         128
#
#     computing_type  iteration  experiment_completed  \
# 0         gpu_a100          0                  True
# 1         gpu_a100          1                  True
# 2         gpu_a100          2                  True
# 3         gpu_a100          3                  True
# 4         gpu_a100          4                  True
# ..             ...        ...                   ...
# 140       gpu_a100          0                  True
# 141       gpu_a100          1                  True
# 142       gpu_a100          2                  True
# 143       gpu_a100          3                  True
# 144       gpu_a100          4                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 1    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 2    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 3    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 4    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# ..                                                 ...
# 140  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 141  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 142  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 143  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 144  /u/dansp/batching_qm9_schnet_unlimited_data_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 1    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 2    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 3    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 4    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# ..                                                 ...                    ...
# 140  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 141  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 142  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 143  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 144  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
#
#      step_10000_train_rmse  step_10000_val_rmse  step_10000_test_rmse  \
# 0                   1.2428               1.2356                1.2349
# 1                   1.2430               1.2358                1.2351
# 2                   1.2426               1.2355                1.2348
# 3                   1.2428               1.2356                1.2349
# 4                   1.2428               1.2356                0.9322
# ..                     ...                  ...                   ...
# 140                 0.9668               0.9643                0.7342
# 141                 0.9665               0.9639                0.9700
# 142                 0.9665               0.7286                0.9701
# 143                 0.9664               0.9636                0.9699
# 144                 0.7312               0.7292                0.9704
#
#      step_10000_batching_time  step_10000_update_time
# 0                      0.0006                  0.0023
# 1                      0.0006                  0.0024
# 2                      0.0006                  0.0023
# 3                      0.0006                  0.0024
# 4                      0.0006                  0.0024
# ..                        ...                     ...
# 140                    2.2915                  2.2960
# 141                    2.2873                  2.2918
# 142                    2.2871                  2.2916
# 143                    2.2793                  2.2838
# 144                    2.2963                  2.3007
#
# [145 rows x 16 columns]

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "dataset": "Algorithm",
    'step_10000_batching_time': 'median batching time (s)',
    'step_10000_update_time': 'median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'median batching time (s)', 'median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()
# Out:
#                       Batch size  median batching time (s)  \
# Algorithm Batch size
# dynamic   16             16.0000                    0.0007
#           32             32.0000                    0.0013
#           64             64.0000                    0.0025
#           128           128.0000                    0.0046
# static    16             16.0000                    0.0679
#           32             32.0000                    0.1790
#           64             64.0000                    0.3216
#
#                       median update time (s)
# Algorithm Batch size
# dynamic   16                          0.0134
#           32                          0.0181
#           64                          0.0428
#           128                         0.0701
# static    16                          0.0835
#           32                          0.2156
#           64                          0.3780

# %% [markdown]
# # AFLOW SchNet

# %%
aflow_schnet_PROFILING_CSV = 'parsed_profiling_aflow_schnet_unlimited_data_10k_steps_12_41__15_02_2024.csv'
profiling_df = pd.read_csv(os.path.join(BASE_DIR, aflow_schnet_PROFILING_CSV))

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "dataset": "Algorithm",
    'step_10000_batching_time': 'median batching time (s)',
    'step_10000_update_time': 'median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'median batching time (s)', 'median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()
# Out:
#                       Batch size  median batching time (s)  \
# Algorithm Batch size
# dynamic   16             16.0000                       NaN
#           32             32.0000                    0.0011
#           64             64.0000                    0.0020
#           128           128.0000                    0.0038
# static    16             16.0000                       NaN
#           32             32.0000                    0.1660
#           64             64.0000                    0.3040
#           128           128.0000                    0.5576
#
#                       median update time (s)
# Algorithm Batch size
# dynamic   16                             NaN
#           32                          0.0178
#           64                          0.0274
#           128                         0.0441
# static    16                             NaN
#           32                          0.1878
#           64                          0.3396
#           128                         0.6128
