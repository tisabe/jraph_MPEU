# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

BASE_DIR = '/home/dts/Documents/hu'
PROFILING_CSV = 'parsed_profiling_static_batching_seb_fix_qm9_aflow_schnet_mpeu_100k_steps_23_05__27_06_2024.csv'

# %%
profiling_df = pd.read_csv(os.path.join(BASE_DIR, PROFILING_CSV))

# %%
profiling_df
# Out:
#       model              time_day dataset batching_type  batching_round_to_64  \
# 0      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 1      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 2      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 3      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 4      MPEU  23_04_06__27_06_2024     qm9        static                 False
# ..      ...                   ...     ...           ...                   ...
# 629  schnet  23_04_11__27_06_2024   aflow        static                  True
# 630  schnet  23_04_11__27_06_2024   aflow        static                  True
# 631  schnet  23_04_12__27_06_2024   aflow        static                  True
# 632  schnet  23_04_12__27_06_2024   aflow        static                  True
# 633  schnet  23_04_12__27_06_2024   aflow        static                  True
#
#      batch_size computing_type  iteration  experiment_completed  \
# 0            16       gpu_a100          0                  True
# 1            16       gpu_a100          1                  True
# 2            16       gpu_a100          2                  True
# 3            16       gpu_a100          3                  True
# 4            16       gpu_a100          4                  True
# ..          ...            ...        ...                   ...
# 629         128       gpu_a100          9                  True
# 630         128            cpu          0                  True
# 631         128            cpu          1                  True
# 632         128            cpu          2                  True
# 633         128            cpu          9                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_both_models_both_datasets_10...
# 1    /u/dansp/batching_both_models_both_datasets_10...
# 2    /u/dansp/batching_both_models_both_datasets_10...
# 3    /u/dansp/batching_both_models_both_datasets_10...
# 4    /u/dansp/batching_both_models_both_datasets_10...
# ..                                                 ...
# 629  /u/dansp/batching_both_models_both_datasets_10...
# 630  /u/dansp/batching_both_models_both_datasets_10...
# 631  /u/dansp/batching_both_models_both_datasets_10...
# 632  /u/dansp/batching_both_models_both_datasets_10...
# 633  /u/dansp/batching_both_models_both_datasets_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_both_models_both_datasets_10...                      3
# 1    /u/dansp/batching_both_models_both_datasets_10...                      3
# 2    /u/dansp/batching_both_models_both_datasets_10...                      3
# 3    /u/dansp/batching_both_models_both_datasets_10...                      3
# 4    /u/dansp/batching_both_models_both_datasets_10...                      3
# ..                                                 ...                    ...
# 629  /u/dansp/batching_both_models_both_datasets_10...                    342
# 630  /u/dansp/batching_both_models_both_datasets_10...                    342
# 631  /u/dansp/batching_both_models_both_datasets_10...                    342
# 632  /u/dansp/batching_both_models_both_datasets_10...                    342
# 633  /u/dansp/batching_both_models_both_datasets_10...                    342
#
#      step_100000_train_rmse  step_100000_val_rmse  step_100000_test_rmse  \
# 0                  0.333098              0.239408               0.336536
# 1                  0.329239              0.320490               0.332788
# 2                  0.330659              0.322810               0.336309
# 3                  0.252252              0.249166               0.347390
# 4                  0.331299              0.323751               0.334804
# ..                      ...                   ...                    ...
# 629                0.176334              0.187531               0.211089
# 630                0.176310              0.187537               0.107383
# 631                0.176310              0.187537               0.107383
# 632                0.176310              0.187537               0.107383
# 633                0.176310              0.187537               0.107383
#
#      step_100000_batching_time_mean  step_100000_update_time_mean  \
# 0                          0.000530                      0.002733
# 1                          0.000536                      0.002744
# 2                          0.000543                      0.002768
# 3                          0.000524                      0.002715
# 4                          0.000526                      0.002702
# ..                              ...                           ...
# 629                        0.002104                      0.010697
# 630                        0.002621                      0.051650
# 631                        0.002613                      0.051851
# 632                        0.002649                      0.051605
# 633                        0.002682                      0.051901
#
#      step_100000_batching_time_median  step_100000_update_time_median
# 0                            0.000520                        0.002632
# 1                            0.000526                        0.002641
# 2                            0.000533                        0.002656
# 3                            0.000514                        0.002618
# 4                            0.000516                        0.002609
# ..                                ...                             ...
# 629                          0.002023                        0.003806
# 630                          0.002466                        0.043707
# 631                          0.002462                        0.044064
# 632                          0.002501                        0.043687
# 633                          0.002540                        0.043939
#
# [634 rows x 19 columns]

# %%
profiling_df[profiling_df['computing_type'] == 'gpu_a100']
# Out:
#       model              time_day dataset batching_type  batching_round_to_64  \
# 0      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 1      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 2      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 3      MPEU  23_04_06__27_06_2024     qm9        static                 False
# 4      MPEU  23_04_06__27_06_2024     qm9        static                 False
# ..      ...                   ...     ...           ...                   ...
# 625  schnet  23_04_11__27_06_2024   aflow        static                  True
# 626  schnet  23_04_11__27_06_2024   aflow        static                  True
# 627  schnet  23_04_11__27_06_2024   aflow        static                  True
# 628  schnet  23_04_11__27_06_2024   aflow        static                  True
# 629  schnet  23_04_11__27_06_2024   aflow        static                  True
#
#      batch_size computing_type  iteration  experiment_completed  \
# 0            16       gpu_a100          0                  True
# 1            16       gpu_a100          1                  True
# 2            16       gpu_a100          2                  True
# 3            16       gpu_a100          3                  True
# 4            16       gpu_a100          4                  True
# ..          ...            ...        ...                   ...
# 625         128       gpu_a100          5                  True
# 626         128       gpu_a100          6                  True
# 627         128       gpu_a100          7                  True
# 628         128       gpu_a100          8                  True
# 629         128       gpu_a100          9                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_both_models_both_datasets_10...
# 1    /u/dansp/batching_both_models_both_datasets_10...
# 2    /u/dansp/batching_both_models_both_datasets_10...
# 3    /u/dansp/batching_both_models_both_datasets_10...
# 4    /u/dansp/batching_both_models_both_datasets_10...
# ..                                                 ...
# 625  /u/dansp/batching_both_models_both_datasets_10...
# 626  /u/dansp/batching_both_models_both_datasets_10...
# 627  /u/dansp/batching_both_models_both_datasets_10...
# 628  /u/dansp/batching_both_models_both_datasets_10...
# 629  /u/dansp/batching_both_models_both_datasets_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_both_models_both_datasets_10...                      3
# 1    /u/dansp/batching_both_models_both_datasets_10...                      3
# 2    /u/dansp/batching_both_models_both_datasets_10...                      3
# 3    /u/dansp/batching_both_models_both_datasets_10...                      3
# 4    /u/dansp/batching_both_models_both_datasets_10...                      3
# ..                                                 ...                    ...
# 625  /u/dansp/batching_both_models_both_datasets_10...                    342
# 626  /u/dansp/batching_both_models_both_datasets_10...                    342
# 627  /u/dansp/batching_both_models_both_datasets_10...                    342
# 628  /u/dansp/batching_both_models_both_datasets_10...                    342
# 629  /u/dansp/batching_both_models_both_datasets_10...                    342
#
#      step_100000_train_rmse  step_100000_val_rmse  step_100000_test_rmse  \
# 0                  0.333098              0.239408               0.336536
# 1                  0.329239              0.320490               0.332788
# 2                  0.330659              0.322810               0.336309
# 3                  0.252252              0.249166               0.347390
# 4                  0.331299              0.323751               0.334804
# ..                      ...                   ...                    ...
# 625                0.176352              0.187537               0.211043
# 626                0.176363              0.187598               0.210365
# 627                0.176324              0.187583               0.211928
# 628                0.174781              0.186360               0.213548
# 629                0.176334              0.187531               0.211089
#
#      step_100000_batching_time_mean  step_100000_update_time_mean  \
# 0                          0.000530                      0.002733
# 1                          0.000536                      0.002744
# 2                          0.000543                      0.002768
# 3                          0.000524                      0.002715
# 4                          0.000526                      0.002702
# ..                              ...                           ...
# 625                        0.002133                      0.010794
# 626                        0.002134                      0.010720
# 627                        0.002124                      0.010768
# 628                        0.002118                      0.010858
# 629                        0.002104                      0.010697
#
#      step_100000_batching_time_median  step_100000_update_time_median
# 0                            0.000520                        0.002632
# 1                            0.000526                        0.002641
# 2                            0.000533                        0.002656
# 3                            0.000514                        0.002618
# 4                            0.000516                        0.002609
# ..                                ...                             ...
# 625                          0.002038                        0.003814
# 626                          0.002053                        0.003829
# 627                          0.002033                        0.003817
# 628                          0.002016                        0.003801
# 629                          0.002023                        0.003806
#
# [320 rows x 19 columns]

# %%
profiling_df[profiling_df['dataset'] == 'aflow']
# Out:
#       model              time_day dataset batching_type  batching_round_to_64  \
# 160    MPEU  23_04_07__27_06_2024   aflow        static                 False
# 161    MPEU  23_04_07__27_06_2024   aflow        static                 False
# 162    MPEU  23_04_07__27_06_2024   aflow        static                 False
# 163    MPEU  23_04_07__27_06_2024   aflow        static                 False
# 164    MPEU  23_04_07__27_06_2024   aflow        static                 False
# ..      ...                   ...     ...           ...                   ...
# 629  schnet  23_04_11__27_06_2024   aflow        static                  True
# 630  schnet  23_04_11__27_06_2024   aflow        static                  True
# 631  schnet  23_04_12__27_06_2024   aflow        static                  True
# 632  schnet  23_04_12__27_06_2024   aflow        static                  True
# 633  schnet  23_04_12__27_06_2024   aflow        static                  True
#
#      batch_size computing_type  iteration  experiment_completed  \
# 160          16       gpu_a100          0                  True
# 161          16       gpu_a100          1                  True
# 162          16       gpu_a100          2                  True
# 163          16       gpu_a100          3                  True
# 164          16       gpu_a100          4                  True
# ..          ...            ...        ...                   ...
# 629         128       gpu_a100          9                  True
# 630         128            cpu          0                  True
# 631         128            cpu          1                  True
# 632         128            cpu          2                  True
# 633         128            cpu          9                  True
#
#                                        submission_path  \
# 160  /u/dansp/batching_both_models_both_datasets_10...
# 161  /u/dansp/batching_both_models_both_datasets_10...
# 162  /u/dansp/batching_both_models_both_datasets_10...
# 163  /u/dansp/batching_both_models_both_datasets_10...
# 164  /u/dansp/batching_both_models_both_datasets_10...
# ..                                                 ...
# 629  /u/dansp/batching_both_models_both_datasets_10...
# 630  /u/dansp/batching_both_models_both_datasets_10...
# 631  /u/dansp/batching_both_models_both_datasets_10...
# 632  /u/dansp/batching_both_models_both_datasets_10...
# 633  /u/dansp/batching_both_models_both_datasets_10...
#
#                                                   path  recompilation_counter  \
# 160  /u/dansp/batching_both_models_both_datasets_10...                      7
# 161  /u/dansp/batching_both_models_both_datasets_10...                      7
# 162  /u/dansp/batching_both_models_both_datasets_10...                      7
# 163  /u/dansp/batching_both_models_both_datasets_10...                      7
# 164  /u/dansp/batching_both_models_both_datasets_10...                      7
# ..                                                 ...                    ...
# 629  /u/dansp/batching_both_models_both_datasets_10...                    342
# 630  /u/dansp/batching_both_models_both_datasets_10...                    342
# 631  /u/dansp/batching_both_models_both_datasets_10...                    342
# 632  /u/dansp/batching_both_models_both_datasets_10...                    342
# 633  /u/dansp/batching_both_models_both_datasets_10...                    342
#
#      step_100000_train_rmse  step_100000_val_rmse  step_100000_test_rmse  \
# 160                  0.3043                0.1353                 0.1501
# 161                  0.3021                0.1343                 0.1501
# 162                  0.3042                0.0885                 0.1499
# 163                  0.3017                0.0882                 0.1500
# 164                  0.2926                0.1349                 0.1455
# ..                      ...                   ...                    ...
# 629                  0.1763                0.1875                 0.2111
# 630                  0.1763                0.1875                 0.1074
# 631                  0.1763                0.1875                 0.1074
# 632                  0.1763                0.1875                 0.1074
# 633                  0.1763                0.1875                 0.1074
#
#      step_100000_batching_time_mean  step_100000_update_time_mean  \
# 160                          0.0005                        0.0026
# 161                          0.0005                        0.0026
# 162                          0.0005                        0.0026
# 163                          0.0005                        0.0026
# 164                          0.0005                        0.0025
# ..                              ...                           ...
# 629                          0.0021                        0.0107
# 630                          0.0026                        0.0517
# 631                          0.0026                        0.0519
# 632                          0.0026                        0.0516
# 633                          0.0027                        0.0519
#
#      step_100000_batching_time_median  step_100000_update_time_median
# 160                            0.0005                          0.0023
# 161                            0.0005                          0.0023
# 162                            0.0005                          0.0023
# 163                            0.0005                          0.0023
# 164                            0.0005                          0.0023
# ..                                ...                             ...
# 629                            0.0020                          0.0038
# 630                            0.0025                          0.0437
# 631                            0.0025                          0.0441
# 632                            0.0025                          0.0437
# 633                            0.0025                          0.0439
#
# [314 rows x 19 columns]

# %%
# AFLOW GPU Schnet round False
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'aflow']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'gpu_a100']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['batching_round_to_64'] == False]

print(gpu_profiling_df.columns)

gpu_profiling_df_batch_32 = gpu_profiling_df[gpu_profiling_df['batch_size'] == 32]
gpu_profiling_df_batch_32 = gpu_profiling_df_batch_32['step_100000_batching_time_mean']
print(gpu_profiling_df_batch_32)


# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_mean': 'Mean batching time (s)',
    'step_100000_update_time_mean': 'Mean update time (s)'})




gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Mean batching time (s)', 'Mean update time (s)']

pd.options.display.float_format = "{:,.5f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
# Index(['model', 'time_day', 'dataset', 'batching_type', 'batching_round_to_64',
#        'batch_size', 'computing_type', 'iteration', 'experiment_completed',
#        'submission_path', 'path', 'recompilation_counter',
#        'step_100000_train_rmse', 'step_100000_val_rmse',
#        'step_100000_test_rmse', 'step_100000_batching_time_mean',
#        'step_100000_update_time_mean', 'step_100000_batching_time_median',
#        'step_100000_update_time_median'],
#       dtype='object')
# 520   NaN
# 521   NaN
# 522   NaN
# 523   NaN
# 524   NaN
# 525   NaN
# 526   NaN
# 527   NaN
# 528   NaN
# 529   NaN
# Name: step_100000_batching_time_mean, dtype: float64
#                       Batch size  Mean batching time (s)  Mean update time (s)
# Algorithm Batch size
# static    16            16.00000                 0.00049               0.00202
#           32            32.00000                     NaN                   NaN
#           64            64.00000                     NaN                   NaN
#           128          128.00000                 0.00210               0.00435

# %%
# Schnet AFLOW ROUND TO MULTIPLE GPU

gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'aflow']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'gpu_a100']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['batching_round_to_64'] == True]

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Batch size'])
list_of_cols_to_display = ['Batch size', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]

gpu_profiling_df_grouped.mean()
# Out:
#             Batch size  Median batching time (s)  Median update time (s)
# Batch size
# 16             16.0000                    0.0005                  0.0018
# 32             32.0000                       NaN                     NaN
# 64             64.0000                       NaN                     NaN
# 128           128.0000                    0.0020                  0.0038

# %%
# Schnet Qm9 GPU - round False
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'qm9']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'gpu_a100']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['batching_round_to_64'] == False]


# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
#                       Batch size  Median batching time (s)  \
# Algorithm Batch size
# static    16             16.0000                       NaN
#           32             32.0000                       NaN
#           64             64.0000                       NaN
#           128           128.0000                    0.0025
#
#                       Median update time (s)
# Algorithm Batch size
# static    16                             NaN
#           32                             NaN
#           64                             NaN
#           128                         0.0438

# %%
# Schnett - AFLOW CPU
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'aflow']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'cpu']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
#                       Batch size  Median batching time (s)  \
# Algorithm Batch size
# static    16             16.0000                    0.0006
#           32             32.0000                       NaN
#           64             64.0000                       NaN
#           128           128.0000                    0.0026
#
#                       Median update time (s)
# Algorithm Batch size
# static    16                          0.0109
#           32                             NaN
#           64                             NaN
#           128                         0.0528

# %%
# Schnet - qm9 CPU
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'qm9']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'cpu']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
#                       Batch size  Median batching time (s)  \
# Algorithm Batch size
# static    16             16.0000                    0.0006
#           32             32.0000                    0.0011
#           64             64.0000                    0.0018
#           128           128.0000                    0.0030
#
#                       Median update time (s)
# Algorithm Batch size
# static    16                          0.0142
#           32                          0.0310
#           64                          0.0494
#           128                         0.0825

# %% [markdown]
# # QM 9 - SchNet

# %%
qm9_schnet_PROFILING_CSV = 'parsed_qm9_schnet_unlimited_10k_steps_07_52__15_02_2024.csv'

# %%
profiling_df = pd.read_csv(os.path.join(BASE_DIR, qm9_schnet_PROFILING_CSV))

# %%
profiling_df
# Out:
#     model              time_day  dataset  batching_type  batch_size  \
# 0     qm9  07_53_33__15_02_2024  dynamic           True          16
# 1     qm9  07_53_33__15_02_2024  dynamic           True          16
# 2     qm9  07_53_33__15_02_2024  dynamic           True          16
# 3     qm9  07_53_33__15_02_2024  dynamic           True          16
# 4     qm9  07_53_33__15_02_2024  dynamic           True          16
# ..    ...                   ...      ...            ...         ...
# 140   qm9  07_53_33__15_02_2024   static           True         128
# 141   qm9  07_53_33__15_02_2024   static           True         128
# 142   qm9  07_53_33__15_02_2024   static           True         128
# 143   qm9  07_53_33__15_02_2024   static           True         128
# 144   qm9  07_53_33__15_02_2024   static           True         128
#
#     computing_type  iteration  experiment_completed  \
# 0         gpu_a100          0                  True
# 1         gpu_a100          1                  True
# 2         gpu_a100          2                  True
# 3         gpu_a100          3                  True
# 4         gpu_a100          4                  True
# ..             ...        ...                   ...
# 140       gpu_a100          0                  True
# 141       gpu_a100          1                  True
# 142       gpu_a100          2                  True
# 143       gpu_a100          3                  True
# 144       gpu_a100          4                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 1    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 2    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 3    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 4    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# ..                                                 ...
# 140  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 141  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 142  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 143  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 144  /u/dansp/batching_qm9_schnet_unlimited_data_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 1    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 2    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 3    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 4    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# ..                                                 ...                    ...
# 140  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 141  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 142  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 143  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 144  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
#
#      step_10000_train_rmse  step_10000_val_rmse  step_10000_test_rmse  \
# 0                   1.2428               1.2356                1.2349
# 1                   1.2430               1.2358                1.2351
# 2                   1.2426               1.2355                1.2348
# 3                   1.2428               1.2356                1.2349
# 4                   1.2428               1.2356                0.9322
# ..                     ...                  ...                   ...
# 140                 0.9668               0.9643                0.7342
# 141                 0.9665               0.9639                0.9700
# 142                 0.9665               0.7286                0.9701
# 143                 0.9664               0.9636                0.9699
# 144                 0.7312               0.7292                0.9704
#
#      step_10000_batching_time  step_10000_update_time
# 0                      0.0006                  0.0023
# 1                      0.0006                  0.0024
# 2                      0.0006                  0.0023
# 3                      0.0006                  0.0024
# 4                      0.0006                  0.0024
# ..                        ...                     ...
# 140                    2.2915                  2.2960
# 141                    2.2873                  2.2918
# 142                    2.2871                  2.2916
# 143                    2.2793                  2.2838
# 144                    2.2963                  2.3007
#
# [145 rows x 16 columns]

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "dataset": "Algorithm",
    'step_10000_batching_time': 'median batching time (s)',
    'step_10000_update_time': 'median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'median batching time (s)', 'median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()
# Out:
#                       Batch size  median batching time (s)  \
# Algorithm Batch size
# dynamic   16             16.0000                    0.0007
#           32             32.0000                    0.0013
#           64             64.0000                    0.0025
#           128           128.0000                    0.0046
# static    16             16.0000                    0.0679
#           32             32.0000                    0.1790
#           64             64.0000                    0.3216
#
#                       median update time (s)
# Algorithm Batch size
# dynamic   16                          0.0134
#           32                          0.0181
#           64                          0.0428
#           128                         0.0701
# static    16                          0.0835
#           32                          0.2156
#           64                          0.3780

# %% [markdown]
# # AFLOW SchNet

# %%
aflow_schnet_PROFILING_CSV = 'parsed_profiling_aflow_schnet_unlimited_data_10k_steps_12_41__15_02_2024.csv'
profiling_df = pd.read_csv(os.path.join(BASE_DIR, aflow_schnet_PROFILING_CSV))

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "dataset": "Algorithm",
    'step_10000_batching_time': 'median batching time (s)',
    'step_10000_update_time': 'median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'median batching time (s)', 'median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()
# Out:
#                       Batch size  median batching time (s)  \
# Algorithm Batch size
# dynamic   16             16.0000                       NaN
#           32             32.0000                    0.0011
#           64             64.0000                    0.0020
#           128           128.0000                    0.0038
# static    16             16.0000                       NaN
#           32             32.0000                    0.1660
#           64             64.0000                    0.3040
#           128           128.0000                    0.5576
#
#                       median update time (s)
# Algorithm Batch size
# dynamic   16                             NaN
#           32                          0.0178
#           64                          0.0274
#           128                         0.0441
# static    16                             NaN
#           32                          0.1878
#           64                          0.3396
#           128                         0.6128
