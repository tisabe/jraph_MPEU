# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

BASE_DIR = '/home/dts/Documents/hu'
PROFILING_CSV = 'parsed_profiling_static_batching_seb_fix_qm9_aflow_schnet_mpeu_100k_steps_17_04__28_03_2024.csv'
ROUND_PROFILING_CSV = 'parsed_profiling_round_to_multiple_qm9_aflow_schnet_100k_steps_23_54__8_03_2024.csv'

# %%
profiling_df = pd.read_csv(os.path.join(BASE_DIR, PROFILING_CSV))
round_profiling_df = pd.read_csv(os.path.join(BASE_DIR, ROUND_PROFILING_CSV))

# %%
profiling_df
# Out:
#       model              time_day dataset batching_type batching_round_to_64  \
# 0      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 1      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 2      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 3      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 4      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# ..      ...                   ...     ...           ...                  ...
# 379  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 380  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 381  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 382  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 383  schnet  17_07_52__28_03_2024   aflow        static           round_True
#
#      batch_size computing_type  iteration  experiment_completed  \
# 0            16       gpu_a100          0                  True
# 1            16       gpu_a100          1                  True
# 2            16       gpu_a100          2                  True
# 3            16       gpu_a100          3                  True
# 4            16       gpu_a100          4                  True
# ..          ...            ...        ...                   ...
# 379         128       gpu_a100          5                  True
# 380         128       gpu_a100          6                  True
# 381         128       gpu_a100          7                  True
# 382         128       gpu_a100          8                  True
# 383         128       gpu_a100          9                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_both_models_both_datasets_10...
# 1    /u/dansp/batching_both_models_both_datasets_10...
# 2    /u/dansp/batching_both_models_both_datasets_10...
# 3    /u/dansp/batching_both_models_both_datasets_10...
# 4    /u/dansp/batching_both_models_both_datasets_10...
# ..                                                 ...
# 379  /u/dansp/batching_both_models_both_datasets_10...
# 380  /u/dansp/batching_both_models_both_datasets_10...
# 381  /u/dansp/batching_both_models_both_datasets_10...
# 382  /u/dansp/batching_both_models_both_datasets_10...
# 383  /u/dansp/batching_both_models_both_datasets_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_both_models_both_datasets_10...                      3
# 1    /u/dansp/batching_both_models_both_datasets_10...                      3
# 2    /u/dansp/batching_both_models_both_datasets_10...                      3
# 3    /u/dansp/batching_both_models_both_datasets_10...                      3
# 4    /u/dansp/batching_both_models_both_datasets_10...                      3
# ..                                                 ...                    ...
# 379  /u/dansp/batching_both_models_both_datasets_10...                    342
# 380  /u/dansp/batching_both_models_both_datasets_10...                    342
# 381  /u/dansp/batching_both_models_both_datasets_10...                    342
# 382  /u/dansp/batching_both_models_both_datasets_10...                    342
# 383  /u/dansp/batching_both_models_both_datasets_10...                    342
#
#      step_100000_train_rmse  step_100000_val_rmse  step_100000_test_rmse  \
# 0                    0.3331                0.2394                 0.3365
# 1                    0.3292                0.3205                 0.3328
# 2                    0.3307                0.3228                 0.3363
# 3                    0.2523                0.2492                 0.3474
# 4                    0.3313                0.3238                 0.3348
# ..                      ...                   ...                    ...
# 379                  0.1764                0.1875                 0.2110
# 380                  0.1764                0.1876                 0.2104
# 381                  0.1763                0.1876                 0.2119
# 382                  0.1748                0.1864                 0.2135
# 383                  0.1763                0.1875                 0.2111
#
#      step_100000_batching_time_mean  step_100000_update_time_mean  \
# 0                            0.0005                        0.0027
# 1                            0.0005                        0.0027
# 2                            0.0005                        0.0028
# 3                            0.0005                        0.0027
# 4                            0.0005                        0.0027
# ..                              ...                           ...
# 379                          0.0021                        0.0108
# 380                          0.0021                        0.0107
# 381                          0.0021                        0.0108
# 382                          0.0021                        0.0109
# 383                          0.0021                        0.0107
#
#      step_100000_batching_time_median  step_100000_update_time_median
# 0                              0.0005                          0.0026
# 1                              0.0005                          0.0026
# 2                              0.0005                          0.0027
# 3                              0.0005                          0.0026
# 4                              0.0005                          0.0026
# ..                                ...                             ...
# 379                            0.0020                          0.0038
# 380                            0.0021                          0.0038
# 381                            0.0020                          0.0038
# 382                            0.0020                          0.0038
# 383                            0.0020                          0.0038
#
# [384 rows x 19 columns]

# %%
profiling_df[profiling_df['computing_type'] == 'gpu_a100']
# Out:
#       model              time_day dataset batching_type batching_round_to_64  \
# 0      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 1      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 2      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 3      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# 4      MPEU  17_07_46__28_03_2024     qm9        static          round_False
# ..      ...                   ...     ...           ...                  ...
# 379  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 380  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 381  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 382  schnet  17_07_52__28_03_2024   aflow        static           round_True
# 383  schnet  17_07_52__28_03_2024   aflow        static           round_True
#
#      batch_size computing_type  iteration  experiment_completed  \
# 0            16       gpu_a100          0                  True
# 1            16       gpu_a100          1                  True
# 2            16       gpu_a100          2                  True
# 3            16       gpu_a100          3                  True
# 4            16       gpu_a100          4                  True
# ..          ...            ...        ...                   ...
# 379         128       gpu_a100          5                  True
# 380         128       gpu_a100          6                  True
# 381         128       gpu_a100          7                  True
# 382         128       gpu_a100          8                  True
# 383         128       gpu_a100          9                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_both_models_both_datasets_10...
# 1    /u/dansp/batching_both_models_both_datasets_10...
# 2    /u/dansp/batching_both_models_both_datasets_10...
# 3    /u/dansp/batching_both_models_both_datasets_10...
# 4    /u/dansp/batching_both_models_both_datasets_10...
# ..                                                 ...
# 379  /u/dansp/batching_both_models_both_datasets_10...
# 380  /u/dansp/batching_both_models_both_datasets_10...
# 381  /u/dansp/batching_both_models_both_datasets_10...
# 382  /u/dansp/batching_both_models_both_datasets_10...
# 383  /u/dansp/batching_both_models_both_datasets_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_both_models_both_datasets_10...                      3
# 1    /u/dansp/batching_both_models_both_datasets_10...                      3
# 2    /u/dansp/batching_both_models_both_datasets_10...                      3
# 3    /u/dansp/batching_both_models_both_datasets_10...                      3
# 4    /u/dansp/batching_both_models_both_datasets_10...                      3
# ..                                                 ...                    ...
# 379  /u/dansp/batching_both_models_both_datasets_10...                    342
# 380  /u/dansp/batching_both_models_both_datasets_10...                    342
# 381  /u/dansp/batching_both_models_both_datasets_10...                    342
# 382  /u/dansp/batching_both_models_both_datasets_10...                    342
# 383  /u/dansp/batching_both_models_both_datasets_10...                    342
#
#      step_100000_train_rmse  step_100000_val_rmse  step_100000_test_rmse  \
# 0                    0.3331                0.2394                 0.3365
# 1                    0.3292                0.3205                 0.3328
# 2                    0.3307                0.3228                 0.3363
# 3                    0.2523                0.2492                 0.3474
# 4                    0.3313                0.3238                 0.3348
# ..                      ...                   ...                    ...
# 379                  0.1764                0.1875                 0.2110
# 380                  0.1764                0.1876                 0.2104
# 381                  0.1763                0.1876                 0.2119
# 382                  0.1748                0.1864                 0.2135
# 383                  0.1763                0.1875                 0.2111
#
#      step_100000_batching_time_mean  step_100000_update_time_mean  \
# 0                            0.0005                        0.0027
# 1                            0.0005                        0.0027
# 2                            0.0005                        0.0028
# 3                            0.0005                        0.0027
# 4                            0.0005                        0.0027
# ..                              ...                           ...
# 379                          0.0021                        0.0108
# 380                          0.0021                        0.0107
# 381                          0.0021                        0.0108
# 382                          0.0021                        0.0109
# 383                          0.0021                        0.0107
#
#      step_100000_batching_time_median  step_100000_update_time_median
# 0                              0.0005                          0.0026
# 1                              0.0005                          0.0026
# 2                              0.0005                          0.0027
# 3                              0.0005                          0.0026
# 4                              0.0005                          0.0026
# ..                                ...                             ...
# 379                            0.0020                          0.0038
# 380                            0.0021                          0.0038
# 381                            0.0020                          0.0038
# 382                            0.0020                          0.0038
# 383                            0.0020                          0.0038
#
# [312 rows x 19 columns]

# %%
round_profiling_df[round_profiling_df['computing_type'] == 'gpu_a100']
# Out:
#       model              time_day dataset batching_type batching_round_to_64  \
# 0    schnet  20_27_44__11_03_2024     qm9        static           round_True
# 1    schnet  20_27_44__11_03_2024     qm9        static           round_True
# 2    schnet  20_27_44__11_03_2024     qm9        static           round_True
# 3    schnet  20_27_44__11_03_2024     qm9        static           round_True
# 4    schnet  20_27_45__11_03_2024     qm9        static           round_True
# ..      ...                   ...     ...           ...                  ...
# 144  schnet  20_27_47__11_03_2024   aflow        static           round_True
# 145  schnet  20_27_47__11_03_2024   aflow        static           round_True
# 146  schnet  20_27_47__11_03_2024   aflow        static           round_True
# 147  schnet  20_27_48__11_03_2024   aflow        static           round_True
# 148  schnet  20_27_48__11_03_2024   aflow        static           round_True
#
#      batch_size computing_type  iteration  experiment_completed  \
# 0            16       gpu_a100          0                  True
# 1            16       gpu_a100          1                  True
# 2            16       gpu_a100          2                  True
# 3            16       gpu_a100          3                  True
# 4            16       gpu_a100          4                  True
# ..          ...            ...        ...                   ...
# 144         128       gpu_a100          5                  True
# 145         128       gpu_a100          6                  True
# 146         128       gpu_a100          7                  True
# 147         128       gpu_a100          8                  True
# 148         128       gpu_a100          9                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 1    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 2    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 3    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 4    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# ..                                                 ...
# 144  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 145  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 146  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 147  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
# 148  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                     60
# 1    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                     60
# 2    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                     60
# 3    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                     60
# 4    /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                     60
# ..                                                 ...                    ...
# 144  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                    342
# 145  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                    342
# 146  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                    342
# 147  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                    342
# 148  /u/dansp/batching_schnet_100k_steps_5_3_2024/p...                    342
#
#      step_100000_train_rmse  step_100000_val_rmse  step_100000_test_rmse  \
# 0                    0.4707                0.3448                 0.4649
# 1                    0.4712                0.4670                 0.4654
# 2                    0.4708                0.4665                 0.4650
# 3                    0.4707                0.4664                 0.4649
# 4                    0.4711                0.4668                 0.4652
# ..                      ...                   ...                    ...
# 144                  0.1016                0.1875                 0.2109
# 145                  0.1763                0.1875                 0.2112
# 146                  0.1763                0.1875                 0.2112
# 147                  0.1763                0.1875                 0.2111
# 148                  0.1763                0.1876                 0.2116
#
#      step_100000_batching_time_mean  step_100000_update_time_mean  \
# 0                            0.0094                        0.0120
# 1                            0.0095                        0.0122
# 2                            0.0095                        0.0121
# 3                            0.0095                        0.0121
# 4                            0.0094                        0.0120
# ..                              ...                           ...
# 144                          0.0409                        0.0497
# 145                          0.0414                        0.0503
# 146                          0.0420                        0.0509
# 147                          0.0411                        0.0500
# 148                          0.0409                        0.0496
#
#      step_100000_batching_time_median  step_100000_update_time_median
# 0                              0.0094                          0.0108
# 1                              0.0094                          0.0108
# 2                              0.0094                          0.0108
# 3                              0.0094                          0.0108
# 4                              0.0094                          0.0107
# ..                                ...                             ...
# 144                            0.0403                          0.0423
# 145                            0.0408                          0.0427
# 146                            0.0414                          0.0433
# 147                            0.0406                          0.0424
# 148                            0.0402                          0.0421
#
# [79 rows x 19 columns]

# %%
# AFLOW GPU
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'aflow']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'gpu']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']

print(gpu_profiling_df.columns)

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_mean': 'Mean batching time (s)',
    'step_100000_update_time_mean': 'Mean update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Mean batching time (s)', 'Mean update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
# Index(['model', 'time_day', 'dataset', 'batching_type', 'batching_round_to_64',
#        'batch_size', 'computing_type', 'iteration', 'experiment_completed',
#        'submission_path', 'path', 'recompilation_counter',
#        'step_100000_train_rmse', 'step_100000_val_rmse',
#        'step_100000_test_rmse', 'step_100000_batching_time_mean',
#        'step_100000_update_time_mean', 'step_100000_batching_time_median',
#        'step_100000_update_time_median'],
#       dtype='object')
# Empty DataFrame
# Columns: [Batch size, Mean batching time (s), Mean update time (s)]
# Index: []

# %%
# AFLOW ROUND TO MULTIPLE GPU

gpu_profiling_df = round_profiling_df[round_profiling_df['dataset'] == 'qm9']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'gpu_a100']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Batch size'])
list_of_cols_to_display = ['Batch size', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]

gpu_profiling_df_grouped.mean()
# Out:
#             Batch size  Median batching time (s)  Median update time (s)
# Batch size
# 16             16.0000                    0.0094                  0.0107
# 32             32.0000                    0.0185                  0.0199
# 64             64.0000                    0.0370                  0.0387
# 128           128.0000                    0.0733                  0.0755

# %%
# Schnet Qm9
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'qm9']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'gpu_a100']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['batching_type'] == 'static']



# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
#                       Batch size  Median batching time (s)  \
# Algorithm Batch size
# static    16             16.0000                    0.0005
#           32             32.0000                    0.0008
#           64             64.0000                    0.0012
#           128           128.0000                    0.0022
#
#                       Median update time (s)
# Algorithm Batch size
# static    16                          0.0019
#           32                          0.0023
#           64                          0.0032
#           128                         0.0053

# %%
# AFLOW CPU
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'aflow']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
#                       Batch size  Median batching time (s)  \
# Algorithm Batch size
# static    16             16.0000                    0.0007
#
#                       Median update time (s)
# Algorithm Batch size
# static    16                          0.0280

# %%
# qm9 CPU
gpu_profiling_df = profiling_df[profiling_df['dataset'] == 'qm9']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['computing_type'] == 'cpu']
gpu_profiling_df = gpu_profiling_df[gpu_profiling_df['model'] == 'schnet']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "batching_type": "Algorithm",
    'step_100000_batching_time_median': 'Median batching time (s)',
    'step_100000_update_time_median': 'Median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'Median batching time (s)', 'Median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.mean()
# Out:
# Empty DataFrame
# Columns: [Batch size, Median batching time (s), Median update time (s)]
# Index: []

# %% [markdown]
# # QM 9 - SchNet

# %%
qm9_schnet_PROFILING_CSV = 'parsed_qm9_schnet_unlimited_10k_steps_07_52__15_02_2024.csv'

# %%
profiling_df = pd.read_csv(os.path.join(BASE_DIR, qm9_schnet_PROFILING_CSV))

# %%
profiling_df
# Out:
#     model              time_day  dataset  batching_type  batch_size  \
# 0     qm9  07_53_33__15_02_2024  dynamic           True          16
# 1     qm9  07_53_33__15_02_2024  dynamic           True          16
# 2     qm9  07_53_33__15_02_2024  dynamic           True          16
# 3     qm9  07_53_33__15_02_2024  dynamic           True          16
# 4     qm9  07_53_33__15_02_2024  dynamic           True          16
# ..    ...                   ...      ...            ...         ...
# 140   qm9  07_53_33__15_02_2024   static           True         128
# 141   qm9  07_53_33__15_02_2024   static           True         128
# 142   qm9  07_53_33__15_02_2024   static           True         128
# 143   qm9  07_53_33__15_02_2024   static           True         128
# 144   qm9  07_53_33__15_02_2024   static           True         128
#
#     computing_type  iteration  experiment_completed  \
# 0         gpu_a100          0                  True
# 1         gpu_a100          1                  True
# 2         gpu_a100          2                  True
# 3         gpu_a100          3                  True
# 4         gpu_a100          4                  True
# ..             ...        ...                   ...
# 140       gpu_a100          0                  True
# 141       gpu_a100          1                  True
# 142       gpu_a100          2                  True
# 143       gpu_a100          3                  True
# 144       gpu_a100          4                  True
#
#                                        submission_path  \
# 0    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 1    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 2    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 3    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 4    /u/dansp/batching_qm9_schnet_unlimited_data_10...
# ..                                                 ...
# 140  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 141  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 142  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 143  /u/dansp/batching_qm9_schnet_unlimited_data_10...
# 144  /u/dansp/batching_qm9_schnet_unlimited_data_10...
#
#                                                   path  recompilation_counter  \
# 0    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 1    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 2    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 3    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 4    /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# ..                                                 ...                    ...
# 140  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 141  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 142  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 143  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
# 144  /u/dansp/batching_qm9_schnet_unlimited_data_10...                      1
#
#      step_10000_train_rmse  step_10000_val_rmse  step_10000_test_rmse  \
# 0                   1.2428               1.2356                1.2349
# 1                   1.2430               1.2358                1.2351
# 2                   1.2426               1.2355                1.2348
# 3                   1.2428               1.2356                1.2349
# 4                   1.2428               1.2356                0.9322
# ..                     ...                  ...                   ...
# 140                 0.9668               0.9643                0.7342
# 141                 0.9665               0.9639                0.9700
# 142                 0.9665               0.7286                0.9701
# 143                 0.9664               0.9636                0.9699
# 144                 0.7312               0.7292                0.9704
#
#      step_10000_batching_time  step_10000_update_time
# 0                      0.0006                  0.0023
# 1                      0.0006                  0.0024
# 2                      0.0006                  0.0023
# 3                      0.0006                  0.0024
# 4                      0.0006                  0.0024
# ..                        ...                     ...
# 140                    2.2915                  2.2960
# 141                    2.2873                  2.2918
# 142                    2.2871                  2.2916
# 143                    2.2793                  2.2838
# 144                    2.2963                  2.3007
#
# [145 rows x 16 columns]

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "dataset": "Algorithm",
    'step_10000_batching_time': 'median batching time (s)',
    'step_10000_update_time': 'median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'median batching time (s)', 'median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()
# Out:
#                       Batch size  median batching time (s)  \
# Algorithm Batch size
# dynamic   16             16.0000                    0.0007
#           32             32.0000                    0.0013
#           64             64.0000                    0.0025
#           128           128.0000                    0.0046
# static    16             16.0000                    0.0679
#           32             32.0000                    0.1790
#           64             64.0000                    0.3216
#
#                       median update time (s)
# Algorithm Batch size
# dynamic   16                          0.0134
#           32                          0.0181
#           64                          0.0428
#           128                         0.0701
# static    16                          0.0835
#           32                          0.2156
#           64                          0.3780

# %% [markdown]
# # AFLOW SchNet

# %%
aflow_schnet_PROFILING_CSV = 'parsed_profiling_aflow_schnet_unlimited_data_10k_steps_12_41__15_02_2024.csv'
profiling_df = pd.read_csv(os.path.join(BASE_DIR, aflow_schnet_PROFILING_CSV))

# %%
gpu_profiling_df = profiling_df[profiling_df['computing_type'] == 'cpu']

# TODO, fix this so that we are using the averages over the ten iterations.
gpu_profiling_df = gpu_profiling_df.rename(columns={
    "batch_size": "Batch size", "dataset": "Algorithm",
    'step_10000_batching_time': 'median batching time (s)',
    'step_10000_update_time': 'median update time (s)'})

gpu_profiling_df_grouped = gpu_profiling_df.groupby(['Algorithm', 'Batch size'])
list_of_cols_to_display = ['Batch size', 'Algorithm', 'median batching time (s)', 'median update time (s)']

pd.options.display.float_format = "{:,.4f}".format

gpu_profiling_df_grouped = gpu_profiling_df_grouped[list_of_cols_to_display]



gpu_profiling_df_grouped.median()
# Out:
#                       Batch size  median batching time (s)  \
# Algorithm Batch size
# dynamic   16             16.0000                       NaN
#           32             32.0000                    0.0011
#           64             64.0000                    0.0020
#           128           128.0000                    0.0038
# static    16             16.0000                       NaN
#           32             32.0000                    0.1660
#           64             64.0000                    0.3040
#           128           128.0000                    0.5576
#
#                       median update time (s)
# Algorithm Batch size
# dynamic   16                             NaN
#           32                          0.0178
#           64                          0.0274
#           128                         0.0441
# static    16                             NaN
#           32                          0.1878
#           64                          0.3396
#           128                         0.6128
