# %%
# import tensorflow
import pandas as pd
tim_aflow_df = pd.read_csv('/home/dts/Downloads/result_best_egap_model_tim.csv')

feature_engineered_aflow_df = pd.read_csv('/home/dts/Downloads/result_best_egap_model_tim_plus_features.csv')

print(feature_engineered_aflow_df.columns)
# Out:
# Index(['EA_half_bar', 'EA_half_hat', 'IP_half_bar', 'IP_half_hat',
#        'EA_delta_bar', 'EA_delta_hat', 'IP_delta_bar', 'IP_delta_hat',
#        'HOMO_bar', 'HOMO_hat', 'LUMO_bar', 'LUMO_hat', 'rs_bar', 'rs_hat',
#        's index_bar', 's index_hat', 'rp_bar', 'rp_hat', 'p index_bar',
#        'p index_hat', 'rd_bar', 'rd_hat', 'd index_bar', 'd index_hat',
#        'rf_bar', 'rf_hat', 'f index_bar', 'f index_hat', 'atomic_number_bar',
#        'atomic_number_hat', 'atomic_weight_bar', 'atomic_weight_hat',
#        'mendeleev_number_bar', 'mendeleev_number_hat', 'melting_point_bar',
#        'melting_point_hat', 'covalent_radius_cordero_bar',
#        'covalent_radius_cordero_hat', 'en_allen_bar', 'en_allen_hat',
#        'en_ghosh_bar', 'en_ghosh_hat', 'en_pauling_bar', 'en_pauling_hat',
#        'period_bar', 'period_hat', 'atomic_volume_bar', 'atomic_volume_hat',
#        'n_valence_bar', 'n_valence_hat', 'HOMO_LUMO_diff_bar',
#        'HOMO_LUMO_diff_hat', 'compound_name'],
#       dtype='object')

# %%
print(len(tim_aflow_df['split']))
# Out:
# 30639

# %%
merged_df = pd.concat([tim_aflow_df.reset_index(drop=True),feature_engineered_aflow_df.reset_index(drop=True)], axis=1)
merged_df.head()
# Out:
#                      auid                                               aurl  \
# 0  aflow:f8b1bfdfa96c51f4  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/BCC/Ca1O3...
# 1  aflow:984e58bbd5bf8ba1  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/MCL/I2Li1...
# 2  aflow:c61ce9bfe3f812a5  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Eu2H6...
# 3  aflow:f3b828e133b46d5e  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2Ga2...
# 4  aflow:53c4293d5c0fa205  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/TRI/Ce2Cl...
#
#    spacegroup_relax Pearson_symbol_relax    Egap           Egap_type  \
# 0             204.0                 cI40  3.5438  insulator-indirect
# 1              14.0                 mP48  2.6186  insulator-indirect
# 2             225.0                 cF36  1.7770  insulator-indirect
# 3             150.0                 hP39  3.8478  insulator-indirect
# 4               2.0                 aP50  0.0516  insulator-indirect
#
#       dft_type  ldau_type  energy_cutoff  energy_atom  ...  en_pauling_hat  \
# 0  ['PAW_PBE']        0.0          560.0     -7.24663  ...        0.955200
# 1  ['PAW_PBE']        2.0          560.0     -5.38166  ...        0.647778
# 2  ['PAW_PBE']        2.0          350.0     -5.69834  ...             NaN
# 3  ['PAW_PBE']        2.0          980.0     -6.42920  ...        0.936095
# 4  ['PAW_PBE']        2.0          560.0     -4.87761  ...        0.589440
#
#   period_bar  period_hat  atomic_volume_bar  atomic_volume_hat n_valence_bar  \
# 0   2.600000    0.720000          16.800000           5.240000      4.800000
# 1   2.666667    1.000000          15.404167           3.431944      5.666667
# 2   2.555556    2.074074          16.744444           5.402469      2.000000
# 3   2.615385    0.852071          17.030769           8.698225      4.307692
# 4   1.720000    0.806400          14.900000           1.400000      3.160000
#
#   n_valence_hat HOMO_LUMO_diff_bar  HOMO_LUMO_diff_hat  compound_name
# 0      1.440000          -0.697848            0.837417      Ca4O12Si4
# 1      0.888889          -1.437500            1.925625     Li4V4I8O32
# 2      1.333333          -0.371796            0.578350        Eu2RuH6
# 3      1.822485          -0.131794            0.223035     Ga6K6B6O21
# 4      2.512000          -0.955228            1.681201   Ce2Cl6H28O14
#
# [5 rows x 72 columns]

# %%
# Now split the data into test and train:

merged_df_removed_na = merged_df.dropna(axis=1)

# %%
merged_df_removed_na[
    merged_df['split'] == 'train']
# Out:
#                          auid  \
# 0      aflow:f8b1bfdfa96c51f4
# 1      aflow:984e58bbd5bf8ba1
# 2      aflow:c61ce9bfe3f812a5
# 3      aflow:f3b828e133b46d5e
# 4      aflow:53c4293d5c0fa205
# ...                       ...
# 24495  aflow:2859d64326b79cbb
# 24496  aflow:92a60bf9be6febeb
# 24497  aflow:1776bd259f10623e
# 24498  aflow:f31aed3d60467950
# 24499  aflow:c3f80b62e2d2ad0f
#
#                                                     aurl  spacegroup_relax  \
# 0      aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/BCC/Ca1O3...             204.0
# 1      aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/MCL/I2Li1...              14.0
# 2      aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Eu2H6...             225.0
# 3      aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2Ga2...             150.0
# 4      aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/TRI/Ce2Cl...               2.0
# ...                                                  ...               ...
# 24495  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/ORC/Mn1O4...              62.0
# 24496  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/MCLC/C2Eu...              15.0
# 24497  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/TRI/Cd1Hg...               2.0
# 24498  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/MCLC/Br2H...              15.0
# 24499  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/MCL/O8Te2...              14.0
#
#       Pearson_symbol_relax    Egap           Egap_type     dft_type  \
# 0                     cI40  3.5438  insulator-indirect  ['PAW_PBE']
# 1                     mP48  2.6186  insulator-indirect  ['PAW_PBE']
# 2                     cF36  1.7770  insulator-indirect  ['PAW_PBE']
# 3                     hP39  3.8478  insulator-indirect  ['PAW_PBE']
# 4                     aP50  0.0516  insulator-indirect  ['PAW_PBE']
# ...                    ...     ...                 ...          ...
# 24495                 oP28  0.5356    insulator-direct  ['PAW_PBE']
# 24496                 mS12  0.4497  insulator-indirect  ['PAW_PBE']
# 24497                 aP20  1.3679  insulator-indirect  ['PAW_PBE']
# 24498                 mS40  3.1851  insulator-indirect  ['PAW_PBE']
# 24499                 mP52  2.8669    insulator-direct  ['PAW_PBE']
#
#        ldau_type  energy_cutoff  energy_atom  ...  \
# 0            0.0          560.0     -7.24663  ...
# 1            2.0          560.0     -5.38166  ...
# 2            2.0          350.0     -5.69834  ...
# 3            2.0          980.0     -6.42920  ...
# 4            2.0          560.0     -4.87761  ...
# ...          ...            ...          ...  ...
# 24495        2.0          560.0     -5.48467  ...
# 24496        2.0          560.0     -9.39370  ...
# 24497        2.0          560.0     -4.47541  ...
# 24498        0.0          560.0     -3.33496  ...
# 24499        2.0          560.0     -6.14793  ...
#
#        covalent_radius_cordero_hat en_ghosh_bar  en_ghosh_hat  period_bar  \
# 0                        37.200000     0.241528      0.075656    2.600000
# 1                        32.777778     0.259005      0.060760    2.666667
# 2                        66.518519     0.233369      0.040575    2.555556
# 3                        39.408284     0.234072      0.075927    2.615385
# 4                        28.268800     0.271370      0.018595    1.720000
# ...                            ...          ...           ...         ...
# 24495                    64.000000     0.223279      0.092909    3.142857
# 24496                    55.555556     0.213162      0.015485    3.333333
# 24497                    29.880000     0.255182      0.059272    3.200000
# 24498                    28.800000     0.264797      0.047734    3.200000
# 24499                    40.899408     0.255920      0.059883    3.461538
#
#        period_hat n_valence_bar n_valence_hat HOMO_LUMO_diff_bar  \
# 0        0.720000      4.800000      1.440000          -0.697848
# 1        1.000000      5.666667      0.888889          -1.437500
# 2        2.074074      2.000000      1.333333          -0.371796
# 3        0.852071      4.307692      1.822485          -0.131794
# 4        0.806400      3.160000      2.512000          -0.955228
# ...           ...           ...           ...                ...
# 24495    1.306122      4.714286      2.122449          -0.311625
# 24496    1.777778      3.333333      0.888889          -2.235115
# 24497    1.480000      7.800000      2.520000          -1.611025
# 24498    1.440000      7.400000      1.840000          -2.634725
# 24499    1.798817      5.230769      1.183432           0.000000
#
#        HOMO_LUMO_diff_hat  compound_name
# 0                0.837417      Ca4O12Si4
# 1                1.925625     Li4V4I8O32
# 2                0.578350        Eu2RuH6
# 3                0.223035     Ga6K6B6O21
# 4                1.681201   Ce2Cl6H28O14
# ...                   ...            ...
# 24495            0.356142      Mn4Rb8O16
# 24496            0.374688          Eu2C4
# 24497            2.255435    Cd2Hg4O12S2
# 24498            3.161670      Hg4Br4O12
# 24499            0.000000    Tl8U4O32Te8
#
# [24500 rows x 66 columns]

# %%
# Save the dataframe for SISSO:


# TODO: only use the columns that the RF finds the best (top 20),
# ideally remove the top correlations too.
columns = [
    'spacegroup_relax',
    'energy_cutoff', 'density',
    'cutoff_val', 'n_edge',
    'EA_half_bar', 'EA_half_hat', 'IP_half_bar', 'IP_half_hat',
    'EA_delta_bar', 'EA_delta_hat', 'IP_delta_bar', 'IP_delta_hat',
    'HOMO_bar', 'HOMO_hat', 'LUMO_bar', 'LUMO_hat', 'rs_bar', 'rs_hat',
    's index_bar', 's index_hat', 'rp_bar', 'rp_hat', 'p index_bar',
    'p index_hat', 'rd_bar', 'rd_hat', 'd index_bar', 'd index_hat',
    'rf_bar', 'rf_hat', 'f index_bar', 'f index_hat', 'atomic_number_bar',
    'atomic_number_hat', 'atomic_weight_bar', 'atomic_weight_hat',
    'mendeleev_number_bar', 'mendeleev_number_hat', 'melting_point_bar',
    'melting_point_hat', 'covalent_radius_cordero_bar',
    'covalent_radius_cordero_hat',
    # 'en_allen_bar', 'en_allen_hat',
    'en_ghosh_bar', 'en_ghosh_hat',
    # 'en_pauling_bar', 'en_pauling_hat',
    'period_bar', 'period_hat',
    # 'atomic_volume_bar',
    # 'atomic_volume_hat',
    'n_valence_bar', 'n_valence_hat', 'HOMO_LUMO_diff_bar',
    'HOMO_LUMO_diff_hat',
    'Egap']



# Now we need to rename the columns.
sisso_df = merged_df_removed_na[columns]
df.rename(columns={"A": "a", "Egap": "Egap (eV)"})

# %%
merged_df_train = merged_df_removed_na[
    merged_df_removed_na['split'] == 'train']
merged_df_val = merged_df_removed_na[
    merged_df_removed_na['split'] == 'validation']
merged_df_test = merged_df_removed_na[
    merged_df_removed_na['split'] == 'test']

columns = [
    'spacegroup_relax',
    'energy_cutoff', 'density',
    'cutoff_val', 'n_edge',
    'EA_half_bar', 'EA_half_hat', 'IP_half_bar', 'IP_half_hat',
    'EA_delta_bar', 'EA_delta_hat', 'IP_delta_bar', 'IP_delta_hat',
    'HOMO_bar', 'HOMO_hat', 'LUMO_bar', 'LUMO_hat', 'rs_bar', 'rs_hat',
    's index_bar', 's index_hat', 'rp_bar', 'rp_hat', 'p index_bar',
    'p index_hat', 'rd_bar', 'rd_hat', 'd index_bar', 'd index_hat',
    'rf_bar', 'rf_hat', 'f index_bar', 'f index_hat', 'atomic_number_bar',
    'atomic_number_hat', 'atomic_weight_bar', 'atomic_weight_hat',
    'mendeleev_number_bar', 'mendeleev_number_hat', 'melting_point_bar',
    'melting_point_hat', 'covalent_radius_cordero_bar',
    'covalent_radius_cordero_hat',
    # 'en_allen_bar', 'en_allen_hat',
    'en_ghosh_bar', 'en_ghosh_hat',
    # 'en_pauling_bar', 'en_pauling_hat',
    'period_bar', 'period_hat',
    # 'atomic_volume_bar',
    # 'atomic_volume_hat',
    'n_valence_bar', 'n_valence_hat', 'HOMO_LUMO_diff_bar',
    'HOMO_LUMO_diff_hat',
    'Egap']

merged_df_removed_bad_features_train = merged_df_train[
    columns]
merged_df_removed_bad_features_test = merged_df_test[
    columns]
merged_df_removed_bad_features_val = merged_df_val[
    columns]

# Print the number of each
training_length = len(merged_df_removed_bad_features_train["Egap"])
test_length = len(merged_df_removed_bad_features_test["Egap"])
print(f'# of training data points: {training_length}')
print(f'# of test data points: {test_length}')
print(
    f'training fraction is: {training_length/(training_length + test_length)}')
    # 'spacegroup_relax', 'energy_cutoff', 'density',
    # 'cutoff_type', 'cutoff_val', 'n_edge']
# Out:
# # of training data points: 24500
# # of test data points: 3085
# training fraction is: 0.8881638571687511

# %%
X_train_df = merged_df_removed_bad_features_train.drop(columns=['Egap'])
y_train_df = merged_df_removed_bad_features_train[['Egap']]


X_val_df = merged_df_removed_bad_features_val.drop(
    columns=['Egap'])
y_val_df = merged_df_removed_bad_features_val[
    ['Egap']]



X_test_df = merged_df_removed_bad_features_test.drop(
    columns=['Egap'])
y_test_df = merged_df_removed_bad_features_test[
    ['Egap']]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression


regr = RandomForestRegressor(min_samples_leaf=10, random_state=42)
regr.fit(X_train_df, y_train_df)
# Out:
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(min_samples_leaf=10, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'bootstrap': [True],
    'max_features': [0.1, 0.3, 0.6],
    'min_samples_leaf': [5, 10, 20],
    'n_estimators': [200, 500, 1000]}


rando_for_gs = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    cv=10, n_jobs=-1, verbose=0, return_train_score=True,
    refit=True)

rando_for_gs.fit(
    X_train_df,
    y_train_df)

print("The Best Params Are:")
print(rando_for_gs.best_params_)

results = pd.DataFrame(rando_for_gs.cv_results_)
print('\n')
print('mean validation scores')
print(rando_for_gs.cv_results_['mean_test_score'])
print(np.mean(rando_for_gs.cv_results_['mean_test_score']))
print(f"minimum validation RMSLE: {np.min(rando_for_gs.cv_results_['mean_test_score'])}")
print(f"maximum validation RMSLE: {np.max(rando_for_gs.cv_results_['mean_test_score'])}")

print('stdev validation scores')
print(rando_for_gs.cv_results_['std_test_score'])

print('\n Train Metrics')
get_metrics_report(aims_y_train, aims_rando_for_gs.predict(aims_X_train), rmsle_plus_1e4=True)
print('\n Test Metrics')
get_metrics_report(aims_y_test, aims_rando_for_gs.predict(aims_X_test), rmsle_plus_1e4=True)
# Out:
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/dts/Documents/hu/jraph_MPEU/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# The Best Params Are:
# {'bootstrap': True, 'max_features': 0.6, 'min_samples_leaf': 5, 'n_estimators': 1000}
#
#
# mean validation scores
# [0.7838518  0.78445397 0.78435414 0.75338018 0.75400797 0.75418542
#  0.71190675 0.71234609 0.71239082 0.79967946 0.8005396  0.80088091
#  0.77334537 0.77403644 0.77414875 0.73459396 0.73549518 0.7356921
#  0.80661462 0.80731471 0.80751107 0.78158942 0.78198451 0.78212224
#  0.74517065 0.74568626 0.74559415]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32703/2974986294.py in <module>
#      25 print('mean validation scores')
#      26 print(rando_for_gs.cv_results_['mean_test_score'])
# ---> 27 print(np.mean(rando_for_gs.cv_results_['mean_test_score']))
#      28 print(f"minimum validation RMSLE: {np.min(rando_for_gs.cv_results_['mean_test_score'])}")
#      29 print(f"maximum validation RMSLE: {np.max(rando_for_gs.cv_results_['mean_test_score'])}")
#
# NameError: name 'np' is not defined

# %%
import numpy as np
# y_val_pred = regr.predict(X_val_df)
y_pred = rando_for_gs.predict(X_test_df)
# Now get statistics on the fit:

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# print(f'The mean absolute error of the val fit is: {mean_absolute_error(y_val_df, y_val_pred)}')
# print(f'The mean root squared error of the val fit is: {np.sqrt(mean_squared_error(y_val_df, y_val_pred))}')

print(f'The mean absolute error of the fit is: {mean_absolute_error(y_test_df, y_pred)}')
print(f'The mean root squared error of the fit is: {np.sqrt(mean_squared_error(y_test_df, y_pred))}')
# Out:
# The mean absolute error of the fit is: 0.4691981558519687
# The mean root squared error of the fit is: 0.7941340098092458

# %%
import numpy as np
# Now get the MdAE
print(y_pred)
np.median(np.abs(y_pred - y_test_df.to_numpy()))
# Out:
# [0.64796797 2.24026574 2.0283473  ... 3.78157656 1.15120295 3.77327122]
# 1.5812893424565586

# %%
importances = rando_for_gs.best_estimator_.feature_importances_
std = np.std([tree.feature_importances_ for tree in rando_for_gs.best_estimator_.estimators_], axis=0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

forest_importances = pd.Series(importances, index=X_test_df.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
# Out:
# Text(0, 0.5, 'Mean decrease in impurity')

# %%
# Save the best model:

import pickle

# save
with open('/home/dts/Downloads/model.pkl','wb') as f:
    pickle.dump(rando_for_gs, f)
